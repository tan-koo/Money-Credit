# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings

from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.ensemble import RandomForestClassifier

warnings.filterwarnings('ignore')

# %%
credit = pd.read_csv('../input/credit.csv')

# %%
credit      #   show data
# Out:
#       CustID  Age          Province  Years  CreditLimit       Payment  \
# 0          1   33           Bangkok      5     300000.0   57728.13158
# 1          2   80           Bangkok      7     280000.0  265570.97240
# 2          3   43           Bangkok      7     250000.0   13891.67981
# 3          4   25            Phuket      6     230000.0   12120.54219
# 4          5   22           Bangkok      6     225000.0  469305.98240
# ...      ...  ...               ...    ...          ...           ...
# 8945    9186   23           Bangkok      3          0.0    3255.94462
# 8946    9187   24            Phuket      3          0.0    2758.61322
# 8947    9188   23           Bangkok      3          0.0     812.70775
# 8948    9189   22            Phuket      3          0.0     525.49959
# 8949    9190   21  Nakornratchasima      3          0.0     631.65404
#
#       Min_payment  Ndefault       Balance  Balance_Freq  N_purchases  \
# 0      4721.03929         1   14092.56223      0.900000           24
# 1      5860.29097         0   31083.93701      0.900000           55
# 2      2628.26661         0    1775.92802      1.000000           25
# 3       687.25483         1     431.03899      0.454545            2
# 4     29740.69421         0  115475.20010      1.000000          101
# ...           ...       ...           ...           ...          ...
# 8945    488.86365         0     284.93517      1.000000            6
# 8946      0.00000         0     191.83215      1.000000            6
# 8947    824.18369         0     233.98673      0.833333            5
# 8948    557.55628         0     134.57564      0.833333            0
# 8949    882.88956         0    3727.08075      0.666667           23
#
#       LastPurchase  MaxPurchase  Inst_purchase       Advance  \
# 0          45696.5      17489.4        28207.1  23301.107800
# 1         265823.4     151589.0       114234.4      0.000000
# 2          14715.5      14715.5            0.0      0.000000
# 3           3700.0       3700.0            0.0      0.000000
# 4         490395.7     407612.5        82783.2   3349.001316
# ...            ...          ...            ...           ...
# 8945        2911.2          0.0         2911.2      0.000000
# 8946        3000.0          0.0         3000.0      0.000000
# 8947        1444.0          0.0         1444.0      0.000000
# 8948           0.0          0.0            0.0    219.352668
# 8949       10932.5      10932.5            0.0    762.240048
#
#       Count_Advance_Tx  Purchase_Freq  Installment_Freq  Advance_Freq  \
# 0             0.700000       0.600000          0.400000             5
# 1             0.900000       0.800000          0.000000             0
# 2             1.000000       0.000000          0.000000             0
# 3             0.166667       0.000000          0.000000             0
# 4             1.000000       0.916667          0.083333             1
# ...                ...            ...               ...           ...
# 8945          1.000000       0.833333          0.000000             0
# 8946          1.000000       0.833333          0.000000             0
# 8947          0.833333       0.666667          0.000000             0
# 8948          0.000000       0.000000          0.166667             2
# 8949          0.666667       0.000000          0.333333             2
#
#       Pct_full_payment
# 0             0.000000
# 1             0.875000
# 2             0.916667
# 3             0.000000
# 4             0.250000
# ...                ...
# 8945          0.500000
# 8946          0.000000
# 8947          0.250000
# 8948          0.250000
# 8949          0.000000
#
# [8950 rows x 20 columns]

# %%
#  remove some columns that are likely not to be used anymore

credit = credit.drop(columns = ['CustID', 'Province', 'LastPurchase', 'Inst_purchase', 'Count_Advance_Tx'])
credit
# Out:
#       Age  Years  CreditLimit       Payment  Min_payment  Ndefault  \
# 0      33      5     300000.0   57728.13158   4721.03929         1
# 1      80      7     280000.0  265570.97240   5860.29097         0
# 2      43      7     250000.0   13891.67981   2628.26661         0
# 3      25      6     230000.0   12120.54219    687.25483         1
# 4      22      6     225000.0  469305.98240  29740.69421         0
# ...   ...    ...          ...           ...          ...       ...
# 8945   23      3          0.0    3255.94462    488.86365         0
# 8946   24      3          0.0    2758.61322      0.00000         0
# 8947   23      3          0.0     812.70775    824.18369         0
# 8948   22      3          0.0     525.49959    557.55628         0
# 8949   21      3          0.0     631.65404    882.88956         0
#
#            Balance  Balance_Freq  N_purchases  MaxPurchase       Advance  \
# 0      14092.56223      0.900000           24      17489.4  23301.107800
# 1      31083.93701      0.900000           55     151589.0      0.000000
# 2       1775.92802      1.000000           25      14715.5      0.000000
# 3        431.03899      0.454545            2       3700.0      0.000000
# 4     115475.20010      1.000000          101     407612.5   3349.001316
# ...            ...           ...          ...          ...           ...
# 8945     284.93517      1.000000            6          0.0      0.000000
# 8946     191.83215      1.000000            6          0.0      0.000000
# 8947     233.98673      0.833333            5          0.0      0.000000
# 8948     134.57564      0.833333            0          0.0    219.352668
# 8949    3727.08075      0.666667           23      10932.5    762.240048
#
#       Purchase_Freq  Installment_Freq  Advance_Freq  Pct_full_payment
# 0          0.600000          0.400000             5          0.000000
# 1          0.800000          0.000000             0          0.875000
# 2          0.000000          0.000000             0          0.916667
# 3          0.000000          0.000000             0          0.000000
# 4          0.916667          0.083333             1          0.250000
# ...             ...               ...           ...               ...
# 8945       0.833333          0.000000             0          0.500000
# 8946       0.833333          0.000000             0          0.000000
# 8947       0.666667          0.000000             0          0.250000
# 8948       0.000000          0.166667             2          0.250000
# 8949       0.000000          0.333333             2          0.000000
#
# [8950 rows x 15 columns]

# %%
credit.info()         #   see data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               8950 non-null   int64
#  1   Years             8950 non-null   int64
#  2   CreditLimit       8950 non-null   float64
#  3   Payment           8950 non-null   float64
#  4   Min_payment       8950 non-null   float64
#  5   Ndefault          8950 non-null   int64
#  6   Balance           8950 non-null   float64
#  7   Balance_Freq      8950 non-null   float64
#  8   N_purchases       8950 non-null   int64
#  9   MaxPurchase       8950 non-null   float64
#  10  Advance           8950 non-null   float64
#  11  Purchase_Freq     8950 non-null   float64
#  12  Installment_Freq  8950 non-null   float64
#  13  Advance_Freq      8950 non-null   int64
#  14  Pct_full_payment  8950 non-null   float64
# dtypes: float64(10), int64(5)
# memory usage: 1.0 MB

# %%
credit.describe()
# Out:
#                Age        Years    CreditLimit        Payment    Min_payment  \
# count  8950.000000  8950.000000    8950.000000    8950.000000    8950.000000
# mean     26.549832     5.807821   31511.873491   17331.438520    8339.834532
# std       6.197564     0.626763   40328.877230   28950.637569   23359.899181
# min      20.000000     3.000000      -9.000000       0.000000       0.000000
# 25%      22.000000     6.000000       0.000000    3832.761660    1630.281637
# 50%      25.000000     6.000000   15000.000000    8569.015460    2896.284025
# 75%      29.000000     6.000000   55000.000000   19011.343167    7887.135008
# max      85.000000     7.000000  300000.000000  507214.833600  764062.075200
#
#           Ndefault        Balance  Balance_Freq  N_purchases    MaxPurchase  \
# count  8950.000000    8950.000000   8950.000000  8950.000000    8950.000000
# mean      0.057207   15644.748277      0.877271    14.709832    5924.373709
# std       0.232250   20815.318795      0.236904    24.857649   16598.879174
# min       0.000000       0.000000      0.000000     0.000000       0.000000
# 25%       0.000000    1282.819155      0.888889     1.000000       0.000000
# 50%       0.000000    8733.852310      1.000000     7.000000     380.000000
# 75%       0.000000   20541.400355      1.000000    17.000000    5774.050000
# max       1.000000  190431.385600      1.000000   358.000000  407612.500000
#
#              Advance  Purchase_Freq  Installment_Freq  Advance_Freq  \
# count    8950.000000    8950.000000       8950.000000   8950.000000
# mean     5873.226675       0.364437          0.135144      3.248827
# std     12582.983260       0.397448          0.200121      6.824647
# min         0.000000       0.000000          0.000000      0.000000
# 25%         0.000000       0.000000          0.000000      0.000000
# 50%         0.000000       0.166667          0.000000      0.000000
# 75%      6682.926836       0.750000          0.222222      4.000000
# max    282823.270600       1.000000          1.500000    123.000000
#
#        Pct_full_payment
# count       8950.000000
# mean           0.153715
# std            0.292499
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.142857
# max            1.000000

# %% [markdown]
# ---

# %% [markdown]
# # ✔️ Elbow Method

# %% [markdown]
# ---

# %%
wcss = []     #   blank list

# %%
# test for 2 - 10 clusters

for k in range(2, 11):
    kmeans = KMeans(n_clusters = k, init = "k-means++")
    kmeans.fit(credit)
    labels = kmeans.labels_
    wcss.append(kmeans.inertia_)
    metrics.silhouette_score(credit, labels, metric = 'euclidean')
    print("silhouette_score of k = " + str(k) + " : {:.2f}  ".format(metrics.silhouette_score(credit, labels,
                                                                                              metric = 'euclidean')))
# Out:
# silhouette_score of k = 2 : 0.52
# silhouette_score of k = 3 : 0.51
# silhouette_score of k = 4 : 0.51
# silhouette_score of k = 5 : 0.43
# silhouette_score of k = 6 : 0.44
# silhouette_score of k = 7 : 0.42
# silhouette_score of k = 8 : 0.39
# silhouette_score of k = 9 : 0.40
# silhouette_score of k = 10 : 0.32

# %%
plt.figure(figsize = (12,6))        
plt.grid()             
plt.plot(range(2,11), wcss, linewidth = 2, color = "red", marker = "8")
plt.xlabel("K Value")
plt.xticks(np.arange(1,11,1))
plt.ylabel("WCSS")
plt.show()

# %%
kmeans = KMeans(n_clusters = 3, random_state = 0)      #  separate into three groups

# %%
kmeans.fit(credit)                  #  training
kmeans.cluster_centers_             #  see centroid
# Out:
# array([[2.45279063e+01, 5.75578168e+00, 1.06729732e+04, 1.12568088e+04,
#         6.38403170e+03, 3.16065372e-02, 1.02297296e+04, 8.60035920e-01,
#         1.13233117e+01, 3.52522990e+03, 3.89894821e+03, 3.54890547e-01,
#         1.19329846e-01, 2.67792168e+00, 1.49161008e-01],
#        [3.11057692e+01, 5.93531469e+00, 8.48187778e+04, 2.31933323e+04,
#         1.27194934e+04, 1.21066434e-01, 2.83877598e+04, 9.24272477e-01,
#         2.05895979e+01, 8.83388715e+03, 9.06940877e+03, 3.82040291e-01,
#         1.68230968e-01, 4.23382867e+00, 1.57870810e-01],
#        [4.18352273e+01, 6.06818182e+00, 1.06482955e+05, 1.64990731e+05,
#         2.34800492e+04, 1.70454545e-01, 4.95413452e+04, 9.01389710e-01,
#         6.30738636e+01, 5.65146011e+04, 3.70795079e+04, 4.87420068e-01,
#         2.87811119e-01, 1.14829545e+01, 2.67496545e-01]])

# %%
# show each group data (cluster center)

credit_group = pd.DataFrame(np.array([[2.45279063e+01, 5.75578168e+00, 1.06729732e+04, 1.12568088e+04,
                                       6.38403170e+03, 3.16065372e-02, 1.02297296e+04, 8.60035920e-01,
                                       1.13233117e+01, 3.52522990e+03, 3.89894821e+03, 3.54890547e-01,
                                       1.19329846e-01, 2.67792168e+00, 1.49161008e-01],
                                      [3.11057692e+01, 5.93531469e+00, 8.48187778e+04, 2.31933323e+04,
                                       1.27194934e+04, 1.21066434e-01, 2.83877598e+04, 9.24272477e-01,
                                       2.05895979e+01, 8.83388715e+03, 9.06940877e+03, 3.82040291e-01,
                                       1.68230968e-01, 4.23382867e+00, 1.57870810e-01],
                                      [4.18352273e+01, 6.06818182e+00, 1.06482955e+05, 1.64990731e+05,
                                       2.34800492e+04, 1.70454545e-01, 4.95413452e+04, 9.01389710e-01,
                                       6.30738636e+01, 5.65146011e+04, 3.70795079e+04, 4.87420068e-01,
                                       2.87811119e-01, 1.14829545e+01, 2.67496545e-01]]),
                            
                            columns = ['Age', 'Years', 'CreditLimit', 'Payment',
                                       'Min_payment', 'Ndefault', 'Balance', 'Balance_Freq',
                                       'N_purchases', 'MaxPurchase', 'Advance', 'Purchase_Freq',
                                       'Installment_Freq', 'Advance_Freq', 'Pct_full_payment'])
credit_group.transpose()
# Out:
#                              0             1              2
# Age                  24.527906     31.105769      41.835227
# Years                 5.755782      5.935315       6.068182
# CreditLimit       10672.973200  84818.777800  106482.955000
# Payment           11256.808800  23193.332300  164990.731000
# Min_payment        6384.031700  12719.493400   23480.049200
# Ndefault              0.031607      0.121066       0.170455
# Balance           10229.729600  28387.759800   49541.345200
# Balance_Freq          0.860036      0.924272       0.901390
# N_purchases          11.323312     20.589598      63.073864
# MaxPurchase        3525.229900   8833.887150   56514.601100
# Advance            3898.948210   9069.408770   37079.507900
# Purchase_Freq         0.354891      0.382040       0.487420
# Installment_Freq      0.119330      0.168231       0.287811
# Advance_Freq          2.677922      4.233829      11.482954
# Pct_full_payment      0.149161      0.157871       0.267497

# %% [markdown]
# ---

# %% [markdown]
# ## Group 1 🧑
#
# Payment and minimum payment are the lowest in 3 groups. The amount of past due payments is the least of the 3 categories in the last three months. The time spent using a credit card is the shortest of the three type as well. Also, requesting for a pay advance is the fewest of the three classes. In summary, this client segment does not frequently utilize a credit card. As a result, the probability of a late fee is minimal.

# %% [markdown]
# ## Group 2 🧔
#
# In the three segments, pay and minimum payment are in the middle. In the past three months, the number of previous invoices has not grown much. Repayment is a respectable level because it exceeds the 75th percentile. This customer group's credit card usage is not particularly noteworthy. As with the prior group, the chance of a late fee is low.

# %% [markdown]
# ## Group 3 🧓
#
# This consumer sector is required to pay the most. The minimum amount is not excessive when compared to payments. This user category uses credit cards the most frequently of the three. With in 3 regions, the maximum payout is the greatest. This customer group is also the most likely to request a money advance. However, they pay their debts the most often. In conclusion, they are skilled at both making and spending money. Therefore, the risk of delayed fee is small, as it was in the two preceding groups.

# %% [markdown]
# ---

# %%
y_kmeans = kmeans.predict(credit)     #  predict
y_kmeans
# Out:
# array([1, 2, 1, ..., 0, 0, 0])

# %%
# add cluster ID into the data

credit['cluster'] = y_kmeans
credit
# Out:
#       Age  Years  CreditLimit       Payment  Min_payment  Ndefault  \
# 0      33      5     300000.0   57728.13158   4721.03929         1
# 1      80      7     280000.0  265570.97240   5860.29097         0
# 2      43      7     250000.0   13891.67981   2628.26661         0
# 3      25      6     230000.0   12120.54219    687.25483         1
# 4      22      6     225000.0  469305.98240  29740.69421         0
# ...   ...    ...          ...           ...          ...       ...
# 8945   23      3          0.0    3255.94462    488.86365         0
# 8946   24      3          0.0    2758.61322      0.00000         0
# 8947   23      3          0.0     812.70775    824.18369         0
# 8948   22      3          0.0     525.49959    557.55628         0
# 8949   21      3          0.0     631.65404    882.88956         0
#
#            Balance  Balance_Freq  N_purchases  MaxPurchase       Advance  \
# 0      14092.56223      0.900000           24      17489.4  23301.107800
# 1      31083.93701      0.900000           55     151589.0      0.000000
# 2       1775.92802      1.000000           25      14715.5      0.000000
# 3        431.03899      0.454545            2       3700.0      0.000000
# 4     115475.20010      1.000000          101     407612.5   3349.001316
# ...            ...           ...          ...          ...           ...
# 8945     284.93517      1.000000            6          0.0      0.000000
# 8946     191.83215      1.000000            6          0.0      0.000000
# 8947     233.98673      0.833333            5          0.0      0.000000
# 8948     134.57564      0.833333            0          0.0    219.352668
# 8949    3727.08075      0.666667           23      10932.5    762.240048
#
#       Purchase_Freq  Installment_Freq  Advance_Freq  Pct_full_payment  cluster
# 0          0.600000          0.400000             5          0.000000        1
# 1          0.800000          0.000000             0          0.875000        2
# 2          0.000000          0.000000             0          0.916667        1
# 3          0.000000          0.000000             0          0.000000        1
# 4          0.916667          0.083333             1          0.250000        2
# ...             ...               ...           ...               ...      ...
# 8945       0.833333          0.000000             0          0.500000        0
# 8946       0.833333          0.000000             0          0.000000        0
# 8947       0.666667          0.000000             0          0.250000        0
# 8948       0.000000          0.166667             2          0.250000        0
# 8949       0.000000          0.333333             2          0.000000        0
#
# [8950 rows x 16 columns]

# %%
# divide 1st group

credit_group1 = credit.loc[credit['cluster'] == 0]
credit_group1 = credit_group1.drop(columns = ['cluster'])
credit_group1
# Out:
#       Age  Years  CreditLimit      Payment  Min_payment  Ndefault  \
# 1103   39      6         80.0  10429.91769   5795.87654         1
# 1115   21      4         80.0   6834.21497  20368.77611         0
# 1120   28      6         80.0   9229.62087   7115.96731         0
# 1163   21      6         80.0  13289.26056   2165.92529         1
# 1188   27      6         80.0  12712.91305   3609.44075         0
# ...   ...    ...          ...          ...          ...       ...
# 8945   23      3          0.0   3255.94462    488.86365         0
# 8946   24      3          0.0   2758.61322      0.00000         0
# 8947   23      3          0.0    812.70775    824.18369         0
# 8948   22      3          0.0    525.49959    557.55628         0
# 8949   21      3          0.0    631.65404    882.88956         0
#
#           Balance  Balance_Freq  N_purchases  MaxPurchase       Advance  \
# 1103  22330.74041      1.000000            4       4452.0      0.000000
# 1115  56560.69801      1.000000            2       3623.6  43442.599160
# 1120  30668.60810      1.000000            9          0.0      0.000000
# 1163  10571.42919      1.000000           21       7399.6      0.000000
# 1188  11721.83909      1.000000           10       9000.0      0.000000
# ...           ...           ...          ...          ...           ...
# 8945    284.93517      1.000000            6          0.0      0.000000
# 8946    191.83215      1.000000            6          0.0      0.000000
# 8947    233.98673      0.833333            5          0.0      0.000000
# 8948    134.57564      0.833333            0          0.0    219.352668
# 8949   3727.08075      0.666667           23      10932.5    762.240048
#
#       Purchase_Freq  Installment_Freq  Advance_Freq  Pct_full_payment
# 1103       0.000000          0.000000             0              0.00
# 1115       0.000000          1.250000            12              0.00
# 1120       0.750000          0.000000             0              0.00
# 1163       0.166667          0.000000             0              0.00
# 1188       0.666667          0.000000             0              0.00
# ...             ...               ...           ...               ...
# 8945       0.833333          0.000000             0              0.50
# 8946       0.833333          0.000000             0              0.00
# 8947       0.666667          0.000000             0              0.25
# 8948       0.000000          0.166667             2              0.25
# 8949       0.000000          0.333333             2              0.00
#
# [6484 rows x 15 columns]

# %%
# divide 2nd group

credit_group2 = credit.loc[credit['cluster'] == 1]
credit_group2 = credit_group2.drop(columns = ['cluster'])
credit_group2
# Out:
#       Age  Years  CreditLimit      Payment   Min_payment  Ndefault  \
# 0      33      5     300000.0  57728.13158    4721.03929         1
# 2      43      7     250000.0  13891.67981    2628.26661         0
# 3      25      6     230000.0  12120.54219     687.25483         1
# 5      24      7     220000.0  42461.68346   42270.81580         0
# 6      59      7     215000.0  32196.21433   30681.25648         0
# ...   ...    ...          ...          ...           ...       ...
# 5488   50      6          0.0  53379.61195   83456.41905         0
# 5657   26      6          0.0  37463.05759  563700.41170         0
# 5830   21      6          0.0  35691.82969  431327.28230         0
# 5968   34      6          0.0  45607.75720  426295.51170         0
# 7132   25      6          0.0   3024.84224  610316.18600         0
#
#            Balance  Balance_Freq  N_purchases  MaxPurchase       Advance  \
# 0      14092.56223      0.900000           24      17489.4  23301.107800
# 2       1775.92802      1.000000           25      14715.5      0.000000
# 3        431.03899      0.454545            2       3700.0      0.000000
# 5     184955.58550      1.000000           76      36573.0      0.000000
# 6     105984.67770      1.000000           13      13004.8      0.000000
# ...            ...           ...          ...          ...           ...
# 5488  163048.89250      1.000000            9          0.0  44544.566680
# 5657   46281.09931      1.000000           21          0.0      0.000000
# 5830   80388.93195      1.000000            0          0.0   1187.493516
# 5968   60222.24462      1.000000            0          0.0  24668.793790
# 7132   90248.12044      1.000000            0          0.0  16502.654390
#
#       Purchase_Freq  Installment_Freq  Advance_Freq  Pct_full_payment
# 0          0.600000          0.400000             5          0.000000
# 2          0.000000          0.000000             0          0.916667
# 3          0.000000          0.000000             0          0.000000
# 5          1.000000          0.000000             0          0.000000
# 6          0.583333          0.000000             0          0.000000
# ...             ...               ...           ...               ...
# 5488       0.416667          0.666667            13          0.000000
# 5657       1.000000          0.000000             0          0.000000
# 5830       0.000000          0.166667             8          0.000000
# 5968       0.000000          0.166667             6          0.000000
# 7132       0.000000          0.083333             2          0.000000
#
# [2290 rows x 15 columns]

# %%
# divide 3rd group

credit_group3 = credit.loc[credit['cluster'] == 2]
credit_group3 = credit_group3.drop(columns = ['cluster'])
credit_group3
# Out:
#       Age  Years  CreditLimit      Payment  Min_payment  Ndefault  \
# 1      80      7     280000.0  265570.9724   5860.29097         0
# 4      22      6     225000.0  469305.9824  29740.69421         0
# 8      78      7     210000.0  197140.9728  14793.09409         1
# 11     24      6     200000.0  117173.0794  60423.91629         1
# 20     29      6     196000.0  390485.9762  53941.73671         0
# ...   ...    ...          ...          ...          ...       ...
# 7277   38      6          0.0  121485.0351   1884.13837         0
# 7426   20      6          0.0  220994.7812   1732.43670         0
# 7553   26      6          0.0  115163.9232   5566.51236         0
# 7645   46      6          0.0  201913.0770  19260.17588         0
# 8237   31      6          0.0  125718.1466   5251.68936         0
#
#            Balance  Balance_Freq  N_purchases  MaxPurchase        Advance  \
# 1      31083.93701      0.900000           55     151589.0       0.000000
# 4     115475.20010      1.000000          101     407612.5    3349.001316
# 8      41940.33835      0.727273           26       4206.0       0.000000
# 11    136730.79610      1.000000          216      39598.1   14666.674430
# 20    109050.53810      1.000000           21       1335.0  282823.270600
# ...            ...           ...          ...          ...            ...
# 7277    5610.03319      1.000000           97     109750.0    5253.498420
# 7426     369.79201      0.181818            0          0.0   25572.720650
# 7553   20173.91656      1.000000          133     112241.0       0.000000
# 7645   70811.71387      1.000000            0          0.0  157164.297200
# 8237   21440.40539      1.000000            0          0.0   84764.799840
#
#       Purchase_Freq  Installment_Freq  Advance_Freq  Pct_full_payment
# 1          0.800000          0.000000             0          0.875000
# 4          0.916667          0.083333             1          0.250000
# 8          0.666667          0.000000             0          0.100000
# 11         1.000000          0.750000            26          0.000000
# 20         0.500000          1.000000           123          0.000000
# ...             ...               ...           ...               ...
# 7277       0.500000          0.250000             6          0.666667
# 7426       0.000000          0.166667             2          0.000000
# 7553       0.500000          0.000000             0          0.333333
# 7645       0.000000          0.909091            69          0.222222
# 8237       0.000000          0.416667            23          0.300000
#
# [176 rows x 15 columns]

# %%
# assign feature & class

yy1 = pd.DataFrame(credit_group1, columns = ['Ndefault'])
XX1 = credit_group1.drop(columns = ['Ndefault'])

yy2 = pd.DataFrame(credit_group2, columns = ['Ndefault'])
XX2 = credit_group2.drop(columns = ['Ndefault'])

yy3 = pd.DataFrame(credit_group3, columns = ['Ndefault'])
XX3 = credit_group3.drop(columns = ['Ndefault'])

# %%
# Split data -> train / test

X_train1, X_test1, y_train1, y_test1 = train_test_split(XX1, yy1, test_size = 0.3, random_state = 0)
X_train2, X_test2, y_train2, y_test2 = train_test_split(XX2, yy2, test_size = 0.3, random_state = 0)
X_train3, X_test3, y_train3, y_test3 = train_test_split(XX3, yy3, test_size = 0.3, random_state = 0)

# %%
# Standardize data (convert to z-score)

scaler = StandardScaler()

X_train_std1 = pd.DataFrame(scaler.fit_transform(X_train1), columns = X_train1.columns)
X_test_std1 = pd.DataFrame(scaler.fit_transform(X_test1), columns = X_test1.columns)

X_train_std2 = pd.DataFrame(scaler.fit_transform(X_train2), columns = X_train2.columns)
X_test_std2 = pd.DataFrame(scaler.fit_transform(X_test2), columns = X_test2.columns)

X_train_std3 = pd.DataFrame(scaler.fit_transform(X_train3), columns = X_train3.columns)
X_test_std3 = pd.DataFrame(scaler.fit_transform(X_test3), columns = X_test3.columns)

# %% [markdown]
# ---

# %% [markdown]
# # 💡 Decision Tree Classifier

# %% [markdown]
# ---

# %%
dt = DecisionTreeClassifier(criterion = "entropy", max_depth = 5)    #   initialize Decision Tree model

# %%
# train model

dt.fit(X_train_std1, y_train1)
dt.fit(X_train_std2, y_train2)
dt.fit(X_train_std3, y_train3)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
# predict

y_pred1 = dt.predict(X_test_std1)
y_pred2 = dt.predict(X_test_std2)
y_pred3 = dt.predict(X_test_std3)

# %%
print(classification_report(y_test1, y_pred1))         # Accuracy group 1
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.85      0.91      1893
#            1       0.06      0.36      0.11        53
#
#     accuracy                           0.84      1946
#    macro avg       0.52      0.61      0.51      1946
# weighted avg       0.95      0.84      0.89      1946

# %%
print(classification_report(y_test2, y_pred2))         # Accuracy group 2
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.89      0.90       620
#            1       0.19      0.25      0.22        67
#
#     accuracy                           0.82       687
#    macro avg       0.55      0.57      0.56       687
# weighted avg       0.85      0.82      0.83       687

# %%
print(classification_report(y_test3, y_pred3))        # Accuracy group 3
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88        44
#            1       0.33      0.22      0.27         9
#
#     accuracy                           0.79        53
#    macro avg       0.59      0.57      0.57        53
# weighted avg       0.76      0.79      0.78        53

# %% [markdown]
# ---

# %% [markdown]
# # 💡 Neural Network Classifier

# %% [markdown]
# ---

# %%
mlp = MLPClassifier(solver = 'lbfgs', hidden_layer_sizes = (10,), random_state = 0)    #  Initialize NN

# %%
# train

mlp.fit(X_train_std1, y_train1)
mlp.fit(X_train_std2, y_train2)
mlp.fit(X_train_std3, y_train3)
# Out:
# MLPClassifier(hidden_layer_sizes=(10,), random_state=0, solver='lbfgs')

# %%
# predict

y_pred1 = mlp.predict(X_test_std1)
y_pred2 = mlp.predict(X_test_std2)
y_pred3 = mlp.predict(X_test_std3)

# %%
print(classification_report(y_test1, y_pred1))         # Accuracy group 1
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.85      0.91      1893
#            1       0.06      0.36      0.10        53
#
#     accuracy                           0.83      1946
#    macro avg       0.52      0.60      0.51      1946
# weighted avg       0.95      0.83      0.89      1946

# %%
print(classification_report(y_test2, y_pred2))         # Accuracy group 2
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90       620
#            1       0.17      0.21      0.19        67
#
#     accuracy                           0.83       687
#    macro avg       0.54      0.55      0.55       687
# weighted avg       0.84      0.83      0.83       687

# %%
print(classification_report(y_test3, y_pred3))         # Accuracy group 3
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90        44
#            1       0.50      0.22      0.31         9
#
#     accuracy                           0.83        53
#    macro avg       0.68      0.59      0.61        53
# weighted avg       0.80      0.83      0.80        53

# %% [markdown]
# ---

# %% [markdown]
# # 💡 Random Forest Classifier

# %% [markdown]
# ---

# %%
#  Initialize RFC

rfc = RandomForestClassifier(n_estimators = 15, max_depth = None, min_samples_split = 2, random_state = 0)

# %%
# train

rfc.fit(X_train_std1, y_train1)
rfc.fit(X_train_std2, y_train2)
rfc.fit(X_train_std3, y_train3)
# Out:
# RandomForestClassifier(n_estimators=15, random_state=0)

# %%
# predict

y_pred1 = rfc.predict(X_test_std1)
y_pred2 = rfc.predict(X_test_std2)
y_pred3 = rfc.predict(X_test_std3)

# %%
print(classification_report(y_test1, y_pred1))         # Accuracy group 1
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1893
#            1       0.04      0.02      0.03        53
#
#     accuracy                           0.96      1946
#    macro avg       0.51      0.50      0.50      1946
# weighted avg       0.95      0.96      0.95      1946

# %%
print(classification_report(y_test2, y_pred2))         # Accuracy group 2
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       620
#            1       0.30      0.04      0.08        67
#
#     accuracy                           0.90       687
#    macro avg       0.60      0.52      0.51       687
# weighted avg       0.85      0.90      0.86       687

# %%
print(classification_report(y_test3, y_pred3))         # Accuracy group 3
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.92        44
#            1       0.75      0.33      0.46         9
#
#     accuracy                           0.87        53
#    macro avg       0.81      0.66      0.69        53
# weighted avg       0.86      0.87      0.85        53
